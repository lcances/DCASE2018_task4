# %%
# Load the required modules
from keras.layers import GRU, Bidirectional, Layer, TimeDistributed, Dense
from keras.models import model_from_json, Model
from keras import backend as K
import matplotlib.pyplot as plt
import matplotlib.patches as patch

import librosa.display
import librosa
import numpy as np
import os, sys
import copy

# %%
# Load the test data create the test dataset
# load the file list
featTestPath = "/homeLocal/eriador/Documents/Corpus/DCASE2018/features_2/test/mel"
featTestList = os.listdir(featTestPath)

# load the meta data ----
metaPath = "/homeLocal/eriador/Documents/Corpus/DCASE2018/meta/test.csv"
with open(metaPath, "r") as metaFile:
    metadata = metaFile.read().splitlines()[1:]
    
metadata = [i.split("\t") for i in metadata]

# load the features
featTest = []
for file in featTestList:
    path = os.path.join(featTestPath, file)
    feature = np.load(path)
    
    # preprocessing
    feature = np.expand_dims(feature, axis=-1)
    featTest.append(feature)
    
featTest = np.array(featTest)

# %%
##### load the model and perform prediction
K.clear_session()
modelJsonPath = "/homeLocal/eriador/Documents/DCASE2018/results/testing/mel_old_noBlank_timeReduction4/oldMel_noBlank_reduce4_model.json"
modelWeightPath = "/homeLocal/eriador/Documents/DCASE2018/results/testing/mel_old_noBlank_timeReduction4/oldMel_noBlank_reduce4_weight.h5py"

with open(modelJsonPath, "r") as modelJsonFile:
    model = model_from_json(modelJsonFile.read())
model.load_weights(modelWeightPath)
model.summary()

intermediate_model = Model(input=model.input, output=model.get_layer("time_distributed_1").output)
intermediate_model.summary()


# retreive information about the custom
prediction = intermediate_model.predict(featTest)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 64, 431, 1)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 64, 431, 64)       640
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 64, 431, 64)       256
# _________________________________________________________________
# activation_1 (Activation)    (None, 64, 431, 64)       0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 215, 64)       0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 16, 215, 64)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 215, 64)       36928
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 16, 215, 64)       256
# _________________________________________________________________
# activation_2 (Activation)    (None, 16, 215, 64)       0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 4, 107, 64)        0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 4, 107, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 4, 107, 64)        36928
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 4, 107, 64)        256
# _________________________________________________________________
# activation_3 (Activation)    (None, 4, 107, 64)        0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 1, 107, 64)        0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 1, 107, 64)        0
# _________________________________________________________________
# reshape_1 (Reshape)          (None, 107, 64)           0
# _________________________________________________________________
# bidirectional_1 (Bidirection (None, 107, 128)          49536
# _________________________________________________________________
# time_distributed_1 (TimeDist (None, 107, 10)           1290
# _________________________________________________________________
# global_average_pooling1d_1 ( (None, 10)                0
# =================================================================
# Total params: 126,090
# Trainable params: 125,706
# Non-trainable params: 384
# _________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 64, 431, 1)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 64, 431, 64)       640
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 64, 431, 64)       256
# _________________________________________________________________
# activation_1 (Activation)    (None, 64, 431, 64)       0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 215, 64)       0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 16, 215, 64)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 215, 64)       36928
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 16, 215, 64)       256
# _________________________________________________________________
# activation_2 (Activation)    (None, 16, 215, 64)       0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 4, 107, 64)        0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 4, 107, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 4, 107, 64)        36928
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 4, 107, 64)        256
# _________________________________________________________________
# activation_3 (Activation)    (None, 4, 107, 64)        0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 1, 107, 64)        0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 1, 107, 64)        0
# _________________________________________________________________
# reshape_1 (Reshape)          (None, 107, 64)           0
# _________________________________________________________________
# bidirectional_1 (Bidirection (None, 107, 128)          49536
# _________________________________________________________________
# time_distributed_1 (TimeDist (None, 107, 10)           1290
# =================================================================
# Total params: 126,090
# Trainable params: 125,706
# Non-trainable params: 384
# _________________________________________________________________
# /homeLocal/eriador/.miniconda3/envs/dcase/lib/python3.6/site-packages/ipykernel_launcher.py:11: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("ti...)`
#   # This is added back by InteractiveShellApp.init_path()

# %%
print(prediction.shape)
# Out:
# (279, 107, 10)

# %%
# process the prediction (intermediate model)
nbFileToDisplay = 40
boundaries = True

classes = "time,Alarm_bell_ringing,Speech,Dog,Cat,Vacuum_cleaner,Dishes,Frying,Electric_shaver_toothbrush,Blender,Running_water".split(",")
output = "time,Alarm_bell_ringing,Speech,Dog,Cat,Vacuum_cleaner,Dishes,Frying,Electric_shaver_toothbrush,Blender,Running_water\n"
Colors = "C0,C0,C1,C2,C3,C4,C5,C6,C7,C8,C9,#c2c2c2".split(",")

def getClasses(file):
    output = ""
    for info in metadata:
        if info[0] == file[:-4]:
            output += ",".join(info[1:]) + "\n"
            
    return output

# display
def drawVLines(file, ax):
    rawBoundaries = getClasses(file[:-4])
    rawBoundaries = rawBoundaries.split("\n")
    print(file[:-8])
    
    
    
def display(filePath):
    with open(filePath, "r") as f:
        raw = f.read().splitlines()[1:]
    data = []
    for r in raw:
        data.append(r.split(","))
    
    data = np.array(data)
    time = np.array(data[:,0], np.float32)
    alarm = np.array(data[:,1], np.float32)
    speech = np.array(data[:,2], np.float32)
    dog = np.array(data[:,3], np.float32)
    cat = np.array(data[:,4], np.float32)
    vac = np.array(data[:,5], np.float32)
    dishes = np.array(data[:,6], np.float32)
    frying = np.array(data[:,7], np.float32)
    elec = np.array(data[:,8], np.float32)
    blend = np.array(data[:,9], np.float32)
    run = np.array(data[:,10], np.float32)
    #blk = np.array(data[:,11], np.float32)
    
    plt.figure()
    fig, ax = plt.subplots(1, figsize=(18,6))
    plt.title(filePath)
    ax.plot(time, alarm, label="alarm", color=Colors[classes.index("Alarm_bell_ringing")])
    ax.plot(time, speech, label="speech", color=Colors[classes.index("Speech")])
    ax.plot(time, dog, label="dog", color=Colors[classes.index("Dog")])
    ax.plot(time, cat, label="cat", color=Colors[classes.index("Cat")])
    ax.plot(time, vac, label="vac", color=Colors[classes.index("Vacuum_cleaner")])
    ax.plot(time, dishes, label="dishes", color=Colors[classes.index("Dishes")])
    ax.plot(time, frying, label="frying", color=Colors[classes.index("Frying")])
    ax.plot(time, elec, label="elec", color=Colors[classes.index("Electric_shaver_toothbrush")])
    ax.plot(time, blend, label="blend", color=Colors[classes.index("Blender")])
    ax.plot(time, run, label="run", color=Colors[classes.index("Running_water")])
    #ax.plot(time, blk, label="blk", color=Colors[classes.index("blank")])
    ax.legend(loc="upper right")
    
    # add patches to highlight ground truth
    tBoundaries = rawBoundaries.split("\n")
    for line in tBoundaries:
        info = line.split(",")
        if len(info) == 3:
            color = Colors[classes.index(info[2])]
            start = float(info[0])
            end = float(info[1]) - float(info[0])
            rect = patch.Rectangle(
                (start,0),end,1,
                linewidth=1,
                edgecolor=color,
                facecolor=color,
                alpha=0.08)
            
            ax.add_patch(rect)

            #plt.axvline(x=info[0], color = Colors[classes.index(info[2])], alpha=0.15)
            #plt.axvline(x=info[1], color = Colors[classes.index(info[2])], alpha=0.15)
        
    plt.show()

for i in range(len(prediction[:nbFileToDisplay])):
    step = prediction.shape[1]
    clip = prediction[i]
    file = featTestList[i]
    print(file)
    rawBoundaries = getClasses(file)
    print(rawBoundaries)
    
    classes = "time,Alarm_bell_ringing,Speech,Dog,Cat,Vacuum_cleaner,Dishes,Frying,Electric_shaver_toothbrush,Blender,Running_water,blank".split(",")
    output = "time,Alarm_bell_ringing,Speech,Dog,Cat,Vacuum_cleaner,Dishes,Frying,Electric_shaver_toothbrush,Blender,Running_water,blank\n"
    
    with open(file + ".csv", "w") as toSave:
        frameCounter = 0
        for frame in clip:
            frameCounter += 10 / step
            output += "%.4f," % frameCounter
            for cls in frame:
                output += "%.4f," % cls
            output += "\n"
        toSave.write(output)
        display(file + ".csv")
# Out:
# Y-mdPX2djAUY_10.000_20.000.wav.npy
# 0.115,1.177,Dog
# 2.9019999999999997,3.895,Dog
# 4.9910000000000005,6.486000000000001,Dog
# 7.53,8.187999999999999,Dog
# 8.956,10.0,Dog
#
# Rectangle(xy=(0.115, 0), width=1.062, height=1, angle=0)
# Rectangle(xy=(2.902, 0), width=0.993, height=1, angle=0)
# Rectangle(xy=(4.991, 0), width=1.495, height=1, angle=0)
# Rectangle(xy=(7.53, 0), width=0.658, height=1, angle=0)
# Rectangle(xy=(8.956, 0), width=1.044, height=1, angle=0)
# Y0cGgIDhIfdA_30.000_40.000.wav.npy
# 3.2960000000000003,4.394,Dog
# 5.003,6.109,Dog
# 7.362,8.988999999999999,Dog
#
# Rectangle(xy=(3.296, 0), width=1.098, height=1, angle=0)
# Rectangle(xy=(5.003, 0), width=1.106, height=1, angle=0)
# Rectangle(xy=(7.362, 0), width=1.627, height=1, angle=0)
# YgY1k1H3JwLw_30.000_40.000.wav.npy
# 0.10400000000000001,1.2409999999999999,Speech
# 1.714,2.787,Speech
# 3.185,7.478,Speech
# 5.712999999999999,10.0,Electric_shaver_toothbrush
# 7.94,8.806000000000001,Speech
#
# Rectangle(xy=(0.104, 0), width=1.137, height=1, angle=0)
# Rectangle(xy=(1.714, 0), width=1.073, height=1, angle=0)
# Rectangle(xy=(3.185, 0), width=4.293, height=1, angle=0)
# Rectangle(xy=(5.713, 0), width=4.287, height=1, angle=0)
# Rectangle(xy=(7.94, 0), width=0.866, height=1, angle=0)
# Y5X8F5Sthk4Q_80.000_90.000.wav.npy
# 0.0,4.659,Running_water
#
# Rectangle(xy=(0, 0), width=4.659, height=1, angle=0)
# Y1FADrYkCEjY_30.000_40.000.wav.npy
# 0.0,1.183,Alarm_bell_ringing
# 1.702,6.226,Speech
# 6.445,8.886000000000001,Speech
#
# Rectangle(xy=(0, 0), width=1.183, height=1, angle=0)
# Rectangle(xy=(1.702, 0), width=4.524, height=1, angle=0)
# Rectangle(xy=(6.445, 0), width=2.441, height=1, angle=0)
# Y6PwBeL3Abl8_60.000_70.000.wav.npy
# 0.0,1.318,Speech
# 2.7939999999999996,4.535,Speech
# 4.129,4.453,Blender
# 4.724,5.335,Blender
# 4.724,6.0760000000000005,Blender
# 5.4,6.0760000000000005,Blender
# 6.635,9.118,Blender
# 9.435,9.882,Blender
#
# Rectangle(xy=(0, 0), width=1.318, height=1, angle=0)
# Rectangle(xy=(2.794, 0), width=1.741, height=1, angle=0)
# Rectangle(xy=(4.129, 0), width=0.324, height=1, angle=0)
# Rectangle(xy=(4.724, 0), width=0.611, height=1, angle=0)
# Rectangle(xy=(4.724, 0), width=1.352, height=1, angle=0)
# Rectangle(xy=(5.4, 0), width=0.676, height=1, angle=0)
# Rectangle(xy=(6.635, 0), width=2.483, height=1, angle=0)
# Rectangle(xy=(9.435, 0), width=0.447, height=1, angle=0)
# YX_Yu2jbBmVc_3.000_13.000.wav.npy
# 5.702999999999999,9.174,Alarm_bell_ringing
#
# Rectangle(xy=(5.703, 0), width=3.471, height=1, angle=0)
# Y8fDeRi8Lqyg_40.000_50.000.wav.npy
# 0.0,10.0,Running_water
#
# Rectangle(xy=(0, 0), width=10, height=1, angle=0)
# Y02sD1KJeoGA_50.000_60.000.wav.npy
# 0.0,10.0,Frying
#
# Rectangle(xy=(0, 0), width=10, height=1, angle=0)
# Y9aNXDP2rv7o_220.000_230.000.wav.npy
# 0.41700000000000004,0.9520000000000001,Speech
# 1.8519999999999999,2.8110000000000004,Speech
# 3.258,3.682,Speech
# 4.107,6.567,Speech
# 6.596,9.846,Blender
# 8.133,9.407,Speech
#
# Rectangle(xy=(0.417, 0), width=0.535, height=1, angle=0)
# Rectangle(xy=(1.852, 0), width=0.959, height=1, angle=0)
# Rectangle(xy=(3.258, 0), width=0.424, height=1, angle=0)
# Rectangle(xy=(4.107, 0), width=2.46, height=1, angle=0)
# Rectangle(xy=(6.596, 0), width=3.25, height=1, angle=0)
# Rectangle(xy=(8.133, 0), width=1.274, height=1, angle=0)
# Y-Bp9Q5aYLOc_70.000_80.000.wav.npy
# 0.0,10.0,Vacuum_cleaner
#
# Rectangle(xy=(0, 0), width=10, height=1, angle=0)
# Y0q87keOtUNQ_21.000_31.000.wav.npy
# 1.5,2.526,Running_water
# 1.787,2.813,Cat
# 3.7230000000000003,4.655,Cat
# 5.9510000000000005,6.712000000000001,Cat
# 7.147,8.636000000000001,Running_water
# 9.171,9.557,Cat
#
# Rectangle(xy=(1.5, 0), width=1.026, height=1, angle=0)
# Rectangle(xy=(1.787, 0), width=1.026, height=1, angle=0)
# Rectangle(xy=(3.723, 0), width=0.932, height=1, angle=0)
# Rectangle(xy=(5.951, 0), width=0.761, height=1, angle=0)
# Rectangle(xy=(7.147, 0), width=1.489, height=1, angle=0)
# Rectangle(xy=(9.171, 0), width=0.386, height=1, angle=0)
# YBuCXr4C5RRc_270.000_280.000.wav.npy
# 0.0,6.617999999999999,Blender
#
# Rectangle(xy=(0, 0), width=6.618, height=1, angle=0)
# YAaFnWKLyP-o_160.000_170.000.wav.npy
# 0.0,2.6489999999999996,Alarm_bell_ringing
# 3.6639999999999997,6.099,Alarm_bell_ringing
# 5.54,7.207999999999999,Speech
#
# Rectangle(xy=(0, 0), width=2.649, height=1, angle=0)
# Rectangle(xy=(3.664, 0), width=2.435, height=1, angle=0)
# Rectangle(xy=(5.54, 0), width=1.668, height=1, angle=0)
# Y-8ju6V8B5Oc_40.000_50.000.wav.npy
# 0.9590000000000001,9.977,Running_water
#
# Rectangle(xy=(0.959, 0), width=9.018, height=1, angle=0)
# Y-K0wP_zCTvA_30.000_40.000.wav.npy
# 0.15,1.7080000000000002,Dog
# 4.172,5.216,Dog
# 5.8629999999999995,6.405,Dog
#
# Rectangle(xy=(0.15, 0), width=1.558, height=1, angle=0)
# Rectangle(xy=(4.172, 0), width=1.044, height=1, angle=0)
# Rectangle(xy=(5.863, 0), width=0.542, height=1, angle=0)
# Y1juKQIs5ePc_50.000_60.000.wav.npy
# 0.0,10.0,Frying
#
# Rectangle(xy=(0, 0), width=10, height=1, angle=0)
# YDOjo6_9WxCo_30.000_40.000.wav.npy
# 0.07,1.047,Speech
# 2.7880000000000003,3.2,Speech
# 3.529,9.982999999999999,Vacuum_cleaner
#
# Rectangle(xy=(0.07, 0), width=0.977, height=1, angle=0)
# Rectangle(xy=(2.788, 0), width=0.412, height=1, angle=0)
# Rectangle(xy=(3.529, 0), width=6.454, height=1, angle=0)
# Y7ZTBswMDOW0_250.000_260.000.wav.npy
# 0.0,10.0,Frying
# 0.0,1.528,Speech
# 1.751,2.309,Speech
# 2.503,5.535,Speech
# 5.711,7.902,Speech
# 8.202,10.0,Speech
#
# Rectangle(xy=(0, 0), width=10, height=1, angle=0)
# Rectangle(xy=(0, 0), width=1.528, height=1, angle=0)
# Rectangle(xy=(1.751, 0), width=0.558, height=1, angle=0)
# Rectangle(xy=(2.503, 0), width=3.032, height=1, angle=0)
# Rectangle(xy=(5.711, 0), width=2.191, height=1, angle=0)
# Rectangle(xy=(8.202, 0), width=1.798, height=1, angle=0)
# Y7agGfavyTX4_120.000_130.000.wav.npy
# 0.0,10.0,Blender
#
# Rectangle(xy=(0, 0), width=10, height=1, angle=0)
# Y1HQyUAfYFHw_0.000_10.000.wav.npy
# 0.121,10.0,Vacuum_cleaner
#
# Rectangle(xy=(0.121, 0), width=9.879, height=1, angle=0)
# YAXpA_dWErVc_530.000_540.000.wav.npy
# 0.0,10.0,Frying
# 7.034,7.68,Dishes
# 7.986000000000001,8.367,Dishes
# 8.785,9.162,Dishes
# 9.502,9.781,Dishes
#
# Rectangle(xy=(0, 0), width=10, height=1, angle=0)
# Rectangle(xy=(7.034, 0), width=0.646, height=1, angle=0)
# Rectangle(xy=(7.986, 0), width=0.381, height=1, angle=0)
# Rectangle(xy=(8.785, 0), width=0.377, height=1, angle=0)
# Rectangle(xy=(9.502, 0), width=0.279, height=1, angle=0)
# Y9V-F5sW1vk8_20.000_30.000.wav.npy
# 0.0,9.988,Blender
# 0.5529999999999999,1.176,Dishes
# 1.694,2.194,Dishes
# 5.224,5.4879999999999995,Dishes
#
# Rectangle(xy=(0, 0), width=9.988, height=1, angle=0)
# Rectangle(xy=(0.553, 0), width=0.623, height=1, angle=0)
# Rectangle(xy=(1.694, 0), width=0.5, height=1, angle=0)
# Rectangle(xy=(5.224, 0), width=0.264, height=1, angle=0)
# Y2DF8mtDke8k_460.000_470.000.wav.npy
# 0.0,10.0,Frying
# 1.218,1.4680000000000002,Dishes
# 1.893,2.263,Dishes
# 2.827,7.98,Speech
# 3.11,3.592,Dishes
# 3.7969999999999997,4.103,Dishes
# 3.7969999999999997,4.492,Dishes
# 4.192,4.492,Dishes
# 7.98,8.23,Dishes
# 7.98,8.617,Dishes
# 8.367,8.617,Dishes
# 8.797,10.0,Dishes
#
# Rectangle(xy=(0, 0), width=10, height=1, angle=0)
# Rectangle(xy=(1.218, 0), width=0.25, height=1, angle=0)
# Rectangle(xy=(1.893, 0), width=0.37, height=1, angle=0)
# Rectangle(xy=(2.827, 0), width=5.153, height=1, angle=0)
# Rectangle(xy=(3.11, 0), width=0.482, height=1, angle=0)
# Rectangle(xy=(3.797, 0), width=0.306, height=1, angle=0)
# Rectangle(xy=(3.797, 0), width=0.695, height=1, angle=0)
# Rectangle(xy=(4.192, 0), width=0.3, height=1, angle=0)
# Rectangle(xy=(7.98, 0), width=0.25, height=1, angle=0)
# Rectangle(xy=(7.98, 0), width=0.637, height=1, angle=0)
# Rectangle(xy=(8.367, 0), width=0.25, height=1, angle=0)
# Rectangle(xy=(8.797, 0), width=1.203, height=1, angle=0)
# Y13YvwUoLde8_10.000_20.000.wav.npy
# 0.0,10.0,Running_water
#
# Rectangle(xy=(0, 0), width=10, height=1, angle=0)
# Y1NbotQwFUTg_30.000_40.000.wav.npy
# 0.32299999999999995,1.375,Dishes
# 1.851,2.4619999999999997,Dishes
# 2.115,10.0,Running_water
# 2.8080000000000003,3.137,Dishes
# 3.478,3.8539999999999996,Dishes
# 5.071000000000001,6.14,Dishes
# 6.586,9.624,Dishes
#
# Rectangle(xy=(0.323, 0), width=1.052, height=1, angle=0)
# Rectangle(xy=(1.851, 0), width=0.611, height=1, angle=0)
# Rectangle(xy=(2.115, 0), width=7.885, height=1, angle=0)
# Rectangle(xy=(2.808, 0), width=0.329, height=1, angle=0)
# Rectangle(xy=(3.478, 0), width=0.376, height=1, angle=0)
# Rectangle(xy=(5.071, 0), width=1.069, height=1, angle=0)
# Rectangle(xy=(6.586, 0), width=3.038, height=1, angle=0)
# Y-9OUFFMZTuk_50.000_60.000.wav.npy
# 0.0,0.7,Dog
# 1.206,3.7289999999999996,Speech
# 1.206,3.853,Dog
# 4.324,5.529,Speech
# 6.082000000000001,6.682,Speech
# 6.871,7.312,Dog
# 8.241,9.853,Speech
# 9.712,10.0,Dog
#
# Rectangle(xy=(0, 0), width=0.7, height=1, angle=0)
# Rectangle(xy=(1.206, 0), width=2.523, height=1, angle=0)
# Rectangle(xy=(1.206, 0), width=2.647, height=1, angle=0)
# Rectangle(xy=(4.324, 0), width=1.205, height=1, angle=0)
# Rectangle(xy=(6.082, 0), width=0.6, height=1, angle=0)
# Rectangle(xy=(6.871, 0), width=0.441, height=1, angle=0)
# Rectangle(xy=(8.241, 0), width=1.612, height=1, angle=0)
# Rectangle(xy=(9.712, 0), width=0.288, height=1, angle=0)
# YCYQJHHZsfA0_20.000_30.000.wav.npy
# 0.0,10.0,Blender
#
# Rectangle(xy=(0, 0), width=10, height=1, angle=0)
# Yi7VpXVrrTPs_30.000_40.000.wav.npy
# 0.0,1.742,Alarm_bell_ringing
# 2.1959999999999997,3.873,Alarm_bell_ringing
#
# Rectangle(xy=(0, 0), width=1.742, height=1, angle=0)
# Rectangle(xy=(2.196, 0), width=1.677, height=1, angle=0)
# YKn1DpReuHy0_120.000_130.000.wav.npy
# 0.852,1.798,Speech
# 1.2570000000000001,10.0,Electric_shaver_toothbrush
# 3.931,5.3,Speech
# 6.157,10.0,Speech
#
# Rectangle(xy=(0.852, 0), width=0.946, height=1, angle=0)
# Rectangle(xy=(1.257, 0), width=8.743, height=1, angle=0)
# Rectangle(xy=(3.931, 0), width=1.369, height=1, angle=0)
# Rectangle(xy=(6.157, 0), width=3.843, height=1, angle=0)
# YJg1jycR1zGQ_30.000_40.000.wav.npy
# 0.0,0.5479999999999999,Speech
# 0.0,10.0,Running_water
# 1.8230000000000002,2.6660000000000004,Speech
# 2.839,3.4389999999999996,Dishes
# 3.716,4.16,Dishes
# 4.53,5.978,Dishes
# 5.545,6.255,Speech
# 7.357,10.0,Speech
# 7.767,8.777000000000001,Dishes
#
# Rectangle(xy=(0, 0), width=0.548, height=1, angle=0)
# Rectangle(xy=(0, 0), width=10, height=1, angle=0)
# Rectangle(xy=(1.823, 0), width=0.843, height=1, angle=0)
# Rectangle(xy=(2.839, 0), width=0.6, height=1, angle=0)
# Rectangle(xy=(3.716, 0), width=0.444, height=1, angle=0)
# Rectangle(xy=(4.53, 0), width=1.448, height=1, angle=0)
# Rectangle(xy=(5.545, 0), width=0.71, height=1, angle=0)
# Rectangle(xy=(7.357, 0), width=2.643, height=1, angle=0)
# Rectangle(xy=(7.767, 0), width=1.01, height=1, angle=0)
# YHGJA33enbP8_40.000_50.000.wav.npy
# 3.821,10.0,Running_water
#
# Rectangle(xy=(3.821, 0), width=6.179, height=1, angle=0)
# Y2yTAfCLLiRs_30.000_40.000.wav.npy
# 4.412,6.297999999999999,Alarm_bell_ringing
# 6.416,7.462000000000001,Speech
# 7.92,10.0,Speech
#
# Rectangle(xy=(4.412, 0), width=1.886, height=1, angle=0)
# Rectangle(xy=(6.416, 0), width=1.046, height=1, angle=0)
# Rectangle(xy=(7.92, 0), width=2.08, height=1, angle=0)
# YUl2QoW9nNls_50.000_60.000.wav.npy
# 0.0,10.0,Running_water
#
# Rectangle(xy=(0, 0), width=10, height=1, angle=0)
# YG3yk9UXVB9g_20.000_30.000.wav.npy
# 0.3,5.124,Speech
# 5.893,10.0,Vacuum_cleaner
#
# Rectangle(xy=(0.3, 0), width=4.824, height=1, angle=0)
# Rectangle(xy=(5.893, 0), width=4.107, height=1, angle=0)
# Y-9P1IlNEgsM_0.000_8.000.wav.npy
# 0.138,1.127,Dog
# 1.454,1.704,Dog
# 2.0540000000000003,2.3040000000000003,Dog
# 2.825,3.075,Dog
# 3.522,3.772,Dog
# 4.312,4.562,Dog
# 4.9719999999999995,5.5889999999999995,Dog
# 5.877000000000001,6.531000000000001,Dog
# 6.777,7.027,Dog
# 7.4510000000000005,7.702999999999999,Dog
#
# Rectangle(xy=(0.138, 0), width=0.989, height=1, angle=0)
# Rectangle(xy=(1.454, 0), width=0.25, height=1, angle=0)
# Rectangle(xy=(2.054, 0), width=0.25, height=1, angle=0)
# Rectangle(xy=(2.825, 0), width=0.25, height=1, angle=0)
# Rectangle(xy=(3.522, 0), width=0.25, height=1, angle=0)
# Rectangle(xy=(4.312, 0), width=0.25, height=1, angle=0)
# Rectangle(xy=(4.972, 0), width=0.617, height=1, angle=0)
# Rectangle(xy=(5.877, 0), width=0.654, height=1, angle=0)
# Rectangle(xy=(6.777, 0), width=0.25, height=1, angle=0)
# Rectangle(xy=(7.451, 0), width=0.252, height=1, angle=0)
# YB4Q6N08yhp8_80.000_90.000.wav.npy
# 2.655,3.8939999999999997,Speech
# 7.106,10.0,Vacuum_cleaner
# 8.429,9.641,Speech
#
# Rectangle(xy=(2.655, 0), width=1.239, height=1, angle=0)
# Rectangle(xy=(7.106, 0), width=2.894, height=1, angle=0)
# Rectangle(xy=(8.429, 0), width=1.212, height=1, angle=0)
# Y30N8kpX42Nc_30.000_40.000.wav.npy
# 0.0,1.3119999999999998,Cat
# 1.953,2.9019999999999997,Cat
# 3.4360000000000004,4.086,Cat
# 4.4719999999999995,5.322,Cat
# 8.868,10.0,Cat
#
# Rectangle(xy=(0, 0), width=1.312, height=1, angle=0)
# Rectangle(xy=(1.953, 0), width=0.949, height=1, angle=0)
# Rectangle(xy=(3.436, 0), width=0.65, height=1, angle=0)
# Rectangle(xy=(4.472, 0), width=0.85, height=1, angle=0)
# Rectangle(xy=(8.868, 0), width=1.132, height=1, angle=0)
# Y-LqG7GIW8UQ_110.000_120.000.wav.npy
# 0.9279999999999999,1.178,Dog
# 2.3209999999999997,2.7089999999999996,Dog
# 3.0669999999999997,5.053,Dog
#
# Rectangle(xy=(0.928, 0), width=0.25, height=1, angle=0)
# Rectangle(xy=(2.321, 0), width=0.388, height=1, angle=0)
# Rectangle(xy=(3.067, 0), width=1.986, height=1, angle=0)
# Y53UtJp-9UYM_100.000_110.000.wav.npy
# 0.0,0.439,Vacuum_cleaner
# 3.824,9.988999999999999,Vacuum_cleaner
#
# Rectangle(xy=(0, 0), width=0.439, height=1, angle=0)
# Rectangle(xy=(3.824, 0), width=6.165, height=1, angle=0)
